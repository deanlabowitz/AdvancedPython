# %%
pip install icecream
# Out:
# Requirement already satisfied: icecream in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (2.1.1)
# Requirement already satisfied: pygments>=2.2.0 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from icecream) (2.8.1)
# Requirement already satisfied: asttokens>=2.0.1 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from icecream) (2.0.5)
# Requirement already satisfied: executing>=0.3.1 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from icecream) (0.8.1)
# Requirement already satisfied: colorama>=0.3.9 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from icecream) (0.4.4)
# Requirement already satisfied: six in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from asttokens>=2.0.1->icecream) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests ## to capture content from web pages
from bs4 import BeautifulSoup ## to parse our scraped data
import pandas as pd ## to easily export our data to dataframes/CSVs
from icecream import ic ## easily debug
from pprint import pprint as pp ## to prettify our printouts
import itertools ## to flatten lists
from random import randrange ## to create a range of numbers
import time # for timer
import json ## to work with JSON data

# %%
## Clean Heat, Commercial Tennant Green Contractors, Commercial/Industrial Solar Installers:
## The three contractor types have totally different target site names, so it made sense 
## to just write them out in a list.

urls = ["https://portal.nyserda.ny.gov/FindAContractorNYSCleanHeat", "https://nyserda-site.force.com/FindAContractorComTenant",
        "https://nyserda-site.secure.force.com/FindAContractorNYSun?programname=NY-Sun%20-%20Commercial%20&%20Industrial"]

# %%
## Scrape all the tables on the urls into a single list of dfs

all_base_dfs = []

for url in urls:
    response = requests.get(url)
#    ic(response.status_code)
    df_list = pd.read_html(response.text)
    df = df_list[0]
    all_base_dfs.append(df)

# %%
## CLEAN HEAT CONTRACTORS

## Each df is different enough to require its own regex for organizing the columns.

## Although the data imports easily as a table, the company info is all jammed together in a single column.
## Target each element using regex and assign it to its own column.
## I would now use re.compile, but I started this before I knew that code! For the sake of time, I'm going w what I got:

df_clean_heat = all_base_dfs[0]

df_clean_heat['Contact_Name'] = df_clean_heat['Company'].str.extract(r'(\s\s\D+)')
## trim off the extra ( included in contact name
df_clean_heat['Contact_Name'] = df_clean_heat['Contact_Name'].str[:-1]

df_clean_heat['Company_Name']= df_clean_heat['Company'].str.extract(r'(^\d*?\D+\s\s)')

df_clean_heat['Phone_Number'] = df_clean_heat['Company'].str.extract(r'(\W\d{3}\W\s\d{3}-\d{4})')

df_clean_heat['Email'] = df_clean_heat['Company'].str.extract(r'(\w+@\w+\D+)')
## trim off the 4 phone number digits that got included in the email
df_clean_heat['Email'] = df_clean_heat['Email'].str[4:]

## The addresses import jammed together without spaces which geopy cannot read. 
## Separate out each address element and connect them with a space.

addressln1_city_state_pat = re.compile(""" (\d+\s\w+\s[\w+\s]*[A-Z][a-z]+) # capture address line 1
                                     ([A-Z][a-z]+[\s\,\w+]*\d{5}) # capture city, state, zip code
                                     """, 
                                        re.M | re.X)
## Clean heat:
df_clean_heat = all_base_dfs[0]
useable_address = []
for company in df_clean_heat["Company"]:
    address_compile = addressln1_city_state_pat.findall(company)
    useable_address.append(address_compile)    
df_clean_heat['Useable_Address'] = useable_address

# %%
## Create a function to create CSV files:

def create_csv(df_name, file_name):
    '''
    Export your dataframe as a csv
    argument 1 = your dataframe name
    argument 2 = your file name as a string. Must include .csv
    For example "my_data.csv"
    '''
    df_name.to_csv(file_name, encoding='utf-8', index=False )
    print(f"{file_name} is in your local folder!")

# %%
## CLEAN HEAT CONTRACTORS

## The regex that isolated the majority of the addresses will be easier to deal with in Excel. 
## Convert the df to csv and clean the remaining addresses from there. ()

create_csv(df_clean_heat, "clean-heat.csv")

# %%
## CLEAN HEAT CONTRACTORS

## Once the data is cleaned, import the csv file back into pandas:

cleaned_clean_heat_df = pd.read_csv (r'cleaned-clean-heat.csv')

# %%
## The other two dfs are much shorter and it's just not worth it to figure out regex for their addresses.
## Send them to csv files and manually deconstruct their addresses
df_com_ten = all_base_dfs[1]
df_solar = all_base_dfs[2]

create_csv(df_com_ten, "com-ten.csv")
create_csv(df_solar,"solar.csv")

# %%
## Once cleaned, import the csv files above back into pandas

cleaned_com_ten_df = pd.read_csv (r'cleaned-com-ten.csv')
cleaned_solar_df = pd.read_csv (r'cleaned-solar.csv')

# %%
## Multi-Family Building Clean Contractors

## This NYSERDA site is totally different from the previous pages and can be imported through the json package

url = "https://www.nyserda.ny.gov/rapi/contractorfinderapi/getmppcontractors?id=b0dcf247-4ea2-4fc4-a3ee-380c34e6faed&counties=&companyname="

## Using the json site found in the "Network" tab of the inspect tab, scrape the page:

response = requests.get(url)
content = response.json() 
target = content.get("Contractors")
multi_fam_df = pd.DataFrame(target)

## The address comes in four parts. Combine them:

multi_fam_df["Address"] = multi_fam_df['Street1EB'] + " " + multi_fam_df['CityEB'] + ' ' + 
                            multi_fam_df['StateEB'] + ' ' + multi_fam_df['Zip5NC']

# %%
## Now, we're ready to start with geocoding. 
## GIS requires the csv files to remain separate, so don't compile

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pandas>=0.25.0 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.2.4)
# Requirement already satisfied: shapely>=1.6 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: certifi in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: click-plugins>=1.0 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: setuptools in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (52.0.0.post20210125)
# Requirement already satisfied: click>=4.0 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages (from geopy) (1.52)
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
## Create a geocoding function and run each df through it. 
##Then download the resulting geocoded dfs to csv files to be used in QGIS


def geocoder(df, address_column_name):
    '''
    Gives the geocode (lat, long) of an address
    df = some dataframe with a column for addresses
    address_column_name = where in the df the addresses are held
    '''
    # Nominatim geocoder for OpenStreetMap data with RateLimiter
    geocoder = RateLimiter(Nominatim(user_agent='tutorial').geocode, min_delay_seconds=1)
    df['Location'] = df[address_column_name].apply(geocoder)

    # add latitude and longitude to dataframe
    df['Latitude'] = df['Location'].apply(lambda loc: loc.latitude if loc else None)
    df['Longitude'] = df['Location'].apply(lambda loc: loc.longitude if loc else None)
    
geocoder(cleaned_clean_heat_df, 'Useable_Address')
geocoder(cleaned_com_ten_df,'Useable_Address')
geocoder(cleaned_solar_df,'Useable_Address')
geocoder(multi_fam_df,'Address')

## With geocodes in hand, download this df to a csv file to manually check the addresses geopy failed to geocode

create_csv(cleaned_clean_heat_df, "clean-clean-clean-CLEAN-clean-heat.csv")
create_csv(cleaned_com_ten_df, "com-ten-lat-long.csv")
create_csv(cleaned_solar_df, "solar-lat-long.csv")
create_csv(multi_fam_df,"multi-family.csv")
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('6711 St Hwy 11 Canton, NY 13617',), **{}).
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 1347, in getresponse
#     response.begin()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6711+St+Hwy+11+Canton%2C+NY+13617&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6711+St+Hwy+11+Canton%2C+NY+13617&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6711+St+Hwy+11+Canton%2C+NY+13617&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('2206 Broadway New York, NY 10024',), **{}).
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 1347, in getresponse
#     response.begin()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('2206 Broadway New York, NY 10024',), **{}).
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 1347, in getresponse
#     response.begin()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('2206 Broadway New York, NY 10024',), **{}).
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 1347, in getresponse
#     response.begin()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/slabowitz/opt/anaconda3/lib/python3.8/site-packages/geopy/adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2206+Broadway+New+York%2C+NY+10024&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
cleaned_clean_heat_df
# Out:
#                                                Company  \
# 0    Reiner Group, Inc.  Anthony Gasparovich(201) 7...
# 1    Perfection Contracting Inc  Sam Qualagari(973)...
# 2    DWC Mechanical, Inc.  Robin Cloy(716) 891-0350...
# 3    Heatwave Heating and Cooling  Robin Cloy(716) ...
# 4    Good-Will Mechanical Corp.  Jenny Li(718) 486-...
# ..                                                 ...
# 511  KL Cooling and Heating  Kalmen Landau(718) 435...
# 512  With Pride Air Conditioning and Heating  Joani...
# 513  WK Mechanical, Inc.  Stephen Conforti(845) 782...
# 514  Wood Well Drilling  Darren Wood(518) 483-2932w...
# 515  Yukos Mechanical, Inc.  Yuri Shneider(845) 300...
#
#                                            Specialties  \
# 0                                       ASHP Installer
# 1    ASHP Installer, GSHP Designer <300,000 Btu/h, ...
# 2                                       ASHP Installer
# 3                                       ASHP Installer
# 4                                       ASHP Installer
# ..                                                 ...
# 511                                     ASHP Installer
# 512                                     ASHP Installer
# 513                                     ASHP Installer
# 514                                       GSHP Driller
# 515                                     ASHP Installer
#
#                                        Counties Served  \
# 0                                             Rockland
# 1    Essex, Monroe, Orange, Rockland, Warren, Westc...
# 2    Cattaraugus, Chautauqua, Erie, Monroe, Niagara...
# 3    Cattaraugus, Chautauqua, Erie, Monroe, Niagara...
# 4          Bronx, New York, Queens, Westchester, Kings
# ..                                                 ...
# 511  Bronx, Delaware, Monroe, New York, Queens, Roc...
# 512        Bronx, New York, Westchester, Nassau, Kings
# 513                 Dutchess, Orange, Ulster, Sullivan
# 514             Clinton, Essex, Franklin, St. Lawrence
# 515   Bronx, New York, Orange, Queens, Rockland, Kings
#
#                                              Utilities  \
# 0                                  Orange and Rockland
# 1    Central Hudson Gas & Electric, Consolidated Ed...
# 2    National Grid, New York State Electric and Gas...
# 3    National Grid, New York State Electric and Gas...
# 4                                  Consolidated Edison
# ..                                                 ...
# 511                                Consolidated Edison
# 512                                Consolidated Edison
# 513  Central Hudson Gas & Electric, New York State ...
# 514     National Grid, New York State Electric and Gas
# 515           Consolidated Edison, Orange and Rockland
#
#     Company Description and Case Studies         Contact_Name  \
# 0                                    NaN  Anthony Gasparovich
# 1                                    NaN        Sam Qualagari
# 2                                    NaN           Robin Cloy
# 3                                    NaN           Robin Cloy
# 4                                    NaN             Jenny Li
# ..                                   ...                  ...
# 511                                  NaN        Kalmen Landau
# 512                                  NaN        Joanie Barton
# 513                                  NaN     Stephen Conforti
# 514                                  NaN          Darren Wood
# 515                                  NaN        Yuri Shneider
#
#                                 Company_Name    Phone_Number  \
# 0                       Reiner Group, Inc.    (201) 794-3700
# 1                 Perfection Contracting Inc  (973) 579-0182
# 2                     DWC Mechanical, Inc.    (716) 891-0350
# 3               Heatwave Heating and Cooling  (716) 891-9283
# 4                 Good-Will Mechanical Corp.  (718) 486-9000
# ..                                       ...             ...
# 511                   KL Cooling and Heating  (718) 435-3991
# 512  With Pride Air Conditioning and Heating  (516) 731-2573
# 513                    WK Mechanical, Inc.    (845) 782-8133
# 514                       Wood Well Drilling  (518) 483-2932
# 515                 Yukos Mechanical, Inc.    (845) 300-6653
#
#                              Email  \
# 0        tgasparovich@reinerac.com
# 1    sam@perfectioncontracting.com
# 2          rcloy@dwcmechanical.com
# 3            rcloy@heatwavewny.com
# 4             jli@goodwillmech.com
# ..                             ...
# 511              kalmen@klnyac.com
# 512       joanie@withpridehvac.net
# 513     sconforti@wkmechanical.com
# 514         wooddrilling@yahoo.com
# 515             yukoslkh@gmail.com
#
#                                 Useable_Address  \
# 0           11-07 River Rd, Fair Lawn, NJ 07410
# 1          1 Camre Dr, Newton, New Jersey 07860
# 2    100 John Glenn Dr, Amherst, New York 14228
# 3    100 John Glenn Dr, Amherst, New York 14228
# 4             1000 Grand St, Brooklyn, NY 11211
# ..                                          ...
# 511            5308 13th Ave Brooklyn, NY 11219
# 512    90 Verdi St. Farmingdale, New York 11735
# 513        546 State Route 17M Monroe, NY 10950
# 514      23285 State Route 11B Bangor, NY 12966
# 515           16 Heritage Dr New City, NY 10956
#
#                                               Location   Latitude  Longitude
# 0    (River Road, Fair Lawn, Bergen County, New Jer...  40.926704 -74.129747
# 1                                                 None        NaN        NaN
# 2    (100, John Glenn Drive, Audubon Industrial Par...  43.031244 -78.806116
# 3    (100, John Glenn Drive, Audubon Industrial Par...  43.031244 -78.806116
# 4    (Grand Street, Queens, Brooklyn, Kings County,...  40.716591 -73.922352
# ..                                                 ...        ...        ...
# 511  (5308, 13th Avenue, Borough Park, Brooklyn, Ki...  40.632618 -73.994837
# 512  (90, Verdi Street, Suffolk County, New York, 1...  40.713446 -73.420930
# 513                                               None        NaN        NaN
# 514                                               None        NaN        NaN
# 515  (16, Heritage Drive, Brownsell Corner, Town of...  41.158896 -73.985003
#
# [516 rows x 13 columns]
